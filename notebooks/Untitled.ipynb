# %%
import gcsfs 


# make sure key json from google is added to local variable by using 
# echo 'export GOOGLE_APPLICATION_CREDENTIALS=/home/path/file.json' >> ~/.aliases

import pandas as pd

# client = storage.Client()
df = pd.read_csv("gcs://wagon-data-750-btc-sent-fc/raw_data/reddit_twitter_fin.csv", index_col='Unnamed: 0') # pull data from google storage
df = df.sort_index(axis=0, ascending=False) # sort on date index and pull most recet 2 dates
df.head()
# Out:
#             n-transactions-per-block    difficulty    utxo-count      mvrv  \
# 2021-11-22               2078.240876  2.267415e+13  7.711521e+07  2.409351
# 2021-11-21               2078.240876  2.267415e+13  7.711521e+07  2.409351
# 2021-11-20               2078.240876  2.267415e+13  7.701882e+07  2.409351
# 2021-11-19               2078.240876  2.267415e+13  7.692242e+07  2.423386
# 2021-11-18               2054.611695  2.267415e+13  7.682603e+07  2.437422
#
#                  nvt  avg-block-size  n-transactions-excluding-popular  \
# 2021-11-22  4.247603        1.275837                     248769.000000
# 2021-11-21  4.247603        1.275837                     248769.000000
# 2021-11-20  4.247603        1.275837                     248769.000000
# 2021-11-19  3.531133        1.275837                     262180.666667
# 2021-11-18  2.814664        1.270386                     275592.333333
#
#             n-unique-addresses  median-confirmation-time  n-payments  ...  \
# 2021-11-22       586185.000000                  6.758333    570982.0  ...
# 2021-11-21       586185.000000                  6.758333    570982.0  ...
# 2021-11-20       632463.333333                  6.758333    623208.0  ...
# 2021-11-19       678741.666667                  7.027778    689992.0  ...
# 2021-11-18       725020.000000                  7.297222    695747.0  ...
#
#                hash-rate  n-transactions-total  n-payments-per-block  \
# 2021-11-22  1.660667e+08           688004340.0           4325.621212
# 2021-11-21  1.660667e+08           688004340.0           4325.621212
# 2021-11-20  1.664277e+08           688004340.0           4297.986207
# 2021-11-19  1.667887e+08           688004340.0           5036.437956
# 2021-11-18  1.671497e+08           687709354.0           4831.576389
#
#             avg-confirmation-time      nvts  transaction-fees-usd  \
# 2021-11-22              18.693389  4.755529         757058.299599
# 2021-11-21              18.693389  4.755529         757058.299599
# 2021-11-20              18.693389  4.755529         757058.299599
# 2021-11-19              18.174117  4.835233         757058.299599
# 2021-11-18              17.654845  4.914937         771114.080949
#
#             active_account  tweets_sent  reddit_crypto_sent  reddit_econ_sent
# 2021-11-22        923541.0     0.235000            0.159344          0.069456
# 2021-11-21        852963.0    -0.022500            0.173188          0.206028
# 2021-11-20        857699.0     0.466667            0.083604          0.014180
# 2021-11-19        968315.0     0.155357            0.058168          0.069516
# 2021-11-18        983663.0    -0.191667            0.129760          0.164820
#
# [5 rows x 24 columns]

# %%
sentiment_topics_data = ['tweets_sent','reddit_crypto_sent','reddit_econ_sent'] # make a list with topics from the df (name of feature)
sentiment_topics_ui = ['Tweeter Econ Sentiment', 'Reddit Crypto Sentiment', 'Reddit Economy Sentiment']

# %%
# get sentiment 
def get_topics_sentiment(sentiment_topics): #get sentiment 
    """ returns a list of lists with with today, yesterday sentiment values, on a scale -100 to 100 for each topic"""
    topics_list = []
    for topic in sentiment_topics:
        
        today_sent = round(df[topic][0]*100, 2)
        yesterday_sent = round(df[topic][1]*100, 2)

        topics_list. append([today_sent, yesterday_sent])
    return topics_list

topics_sentiments = get_topics_sentiment(sentiment_topics_data)
topics_sentiments
# Out:
# [[23.5, -2.25], [15.93, 17.32], [6.95, 20.6]]

# %%
btc_today = topics_sentiments[2][0]
btc_diff =  round(abs(topics_sentiments[2][0]) - abs(topics_sentiments[2][1]), 2)
btc_diff
# Out:
# -13.65

# %%
df[sentiment_topics_data[0]][0:30].to_list()
# Out:
# [0.235,
#  -0.0225,
#  0.4666666666666666,
#  0.1553571428571428,
#  -0.1916666666666666,
#  0.0041666666666666,
#  -0.15,
#  0.0499999999999999,
#  0.0,
#  -0.4046296296296297,
#  0.1148701298701298,
#  0.1041666666666666,
#  -0.35,
#  0.2333333333333333,
#  0.0226190476190476,
#  0.0,
#  0.0696428571428571,
#  -0.2312499999999999,
#  0.1666666666666666,
#  0.1406547619047619,
#  0.0,
#  0.04,
#  0.1239583333333333,
#  0.125,
#  0.2083333333333333,
#  -0.5722222222222222,
#  0.1270833333333333,
#  -0.0083333333333333,
#  0.0711904761904761,
#  0.19]
